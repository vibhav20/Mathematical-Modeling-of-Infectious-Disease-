# %%
import geopandas as gpd

import os
os.environ['SHAPE_RESTORE_SHX'] = 'YES'

# %%
gdf = gpd.read_file('Yellow Fever/data/gaul-districts/g2015_2014_2.shp')

# Display the GeoDataFrame
# Out:
#                                             geometry
# 0  POLYGON ((29.79610 -3.62673, 29.79516 -3.63288...
# 1  POLYGON ((29.82561 -3.36665, 29.82506 -3.36981...
# 2  POLYGON ((29.60733 -3.78270, 29.60393 -3.78899...
# 3  POLYGON ((29.49645 -3.66299, 29.49792 -3.66422...
# 4  POLYGON ((29.53687 -4.19135, 29.53699 -4.19171...

# %%
gdf.shape
# Out:
# (38258, 1)

# %%
gdf.plot()
# Out:
# <Axes: >
